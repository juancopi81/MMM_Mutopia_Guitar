# %% [markdown]
# # Notebook to hear your generated tokens

# %% [markdown]
# This notebook is adapted from [the one created by Dr. Tristan Behrens](https://huggingface.co/TristanBehrens/js-fakes-4bars)

# %%
# Add the tokens generated by the model between the quotation marks
first_piece = "PIECE_START TIME_SIGNATURE=4_4 BPM=120 TRACK_START INST=0 DENSITY=2 BAR_START NOTE_ON=60 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=58 NOTE_ON=75 NOTE_OFF=65 TIME_DELTA=1.3333333333333333 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=75 NOTE_ON=65 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=70 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=70 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=70 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=55 TIME_DELTA=1.0 NOTE_OFF=70 NOTE_ON=70 TIME_DELTA=1.0 NOTE_OFF=70 NOTE_ON=79 NOTE_OFF=55 TIME_DELTA=1.0 NOTE_ON=53 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=55 TIME_DELTA=1.0 NOTE_OFF=55 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=53 NOTE_OFF=58 BAR_END BAR_START NOTE_ON=58 TIME_DELTA=1.0 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=58 NOTE_ON=69 NOTE_OFF=65 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=69 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=72 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=72 NOTE_ON=65 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=67 TIME_DELTA=1.0 NOTE_OFF=67 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=79 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=79 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 BAR_END BAR_START NOTE_ON=65 TIME_DELTA=1.0 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=77 NOTE_OFF=57 TIME_DELTA=1.0 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=53 NOTE_ON=48 NOTE_OFF=65 TIME_DELTA=1.0 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=48 NOTE_OFF=57 BAR_END BAR_START NOTE_ON=58 TIME_DELTA=1.0 NOTE_ON=62 TIME_DELTA=1.0 NOTE_OFF=62 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=74 TIME_DELTA=1.0 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=74 NOTE_ON=65 NOTE_OFF=65 TIME_DELTA=1.0 NOTE_OFF=58 NOTE_ON=64 NOTE_OFF=65 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=64 NOTE_ON=74 TIME_DELTA=1.0 NOTE_OFF=74 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=74 TIME_DELTA=1.0 NOTE_OFF=74 NOTE_ON=70 TIME_DELTA=1.0 NOTE_OFF=70 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=58 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=58 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=60 BAR_END BAR_START NOTE_ON=60 TIME_DELTA=1.0 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=72 TIME_DELTA=1.0 NOTE_OFF=72 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=57 NOTE_OFF=57 TIME_DELTA=1.0 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=57 NOTE_OFF=57 TIME_DELTA=1.0 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=72 NOTE_OFF=65 NOTE_OFF=57 BAR_END NOTE_OFF=50 NOTE_OFF=57 NOTE_ON=58 NOTE_OFF=57 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=62 TIME_DELTA=1.0 NOTE_OFF=57 BAR_END BAR_START NOTE_OFF=57 NOTE_ON=53 NOTE_OFF=57 NOTE_ON=65 TIME_DELTA=1.0 NOTE_ON=57 NOTE_OFF=65 NOTE_ON=72 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=53 NOTE_OFF=57 NOTE_ON=41 NOTE_OFF=57 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=55 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=60 TIME_DELTA=1.0 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=53 TIME_DELTA=1.0 NOTE_ON=60 TIME_DELTA=1.0 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=62 TIME_DELTA=1.0 NOTE_OFF=53 NOTE_ON=48 NOTE_OFF=57 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=55 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=53 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=57 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=72 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=57 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=72 TIME_DELTA=1.0 NOTE_OFF=57"
first_piece
# Out:
# 'PIECE_START TIME_SIGNATURE=4_4 BPM=120 TRACK_START INST=0 DENSITY=2 BAR_START NOTE_ON=60 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=58 NOTE_ON=75 NOTE_OFF=65 TIME_DELTA=1.3333333333333333 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=75 NOTE_ON=65 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=70 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=70 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=70 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=55 TIME_DELTA=1.0 NOTE_OFF=70 NOTE_ON=70 TIME_DELTA=1.0 NOTE_OFF=70 NOTE_ON=79 NOTE_OFF=55 TIME_DELTA=1.0 NOTE_ON=53 NOTE_OFF=58 TIME_DELTA=1.0 NOTE_ON=55 TIME_DELTA=1.0 NOTE_OFF=55 NOTE_ON=58 TIME_DELTA=1.0 NOTE_OFF=53 NOTE_OFF=58 BAR_END BAR_START NOTE_ON=58 TIME_DELTA=1.0 NOTE_ON=60 TIME_DELTA=1.0 NOTE_OFF=60 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=65 NOTE_ON=65 TIME_DELTA=1.0 NOTE_OFF=58 NOTE_ON=69 NOTE_OFF=65 TIME_DELTA=1.0 NOTE_ON=58 TIME_DELTA=1.
# ...

# %%
# !pip install note_seq
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import note_seq
import copy
import random

# %%
len(first_piece.split())
# Out:
# 350

# %%
BPM_1_SECOND = 60

# Variables to change based on the time signature
numerator = ""
denominator = ""

def token_sequence_to_note_sequence(token_sequence, 
                                    use_program=True, 
                                    use_drums=True, 
                                    instrument_mapper=None, 
                                    only_piano=False):

    if isinstance(token_sequence, str):
        token_sequence = token_sequence.split()

    note_sequence = empty_note_sequence()

    # Render all notes.
    current_program = 1
    current_is_drum = False
    current_instrument = 0
    track_count = 0
    for token_index, token in enumerate(token_sequence):

        if token == "PIECE_START":
            pass
        elif token == "PIECE_END":
            print("The end.")
            break
        elif token.startswith("TIME_SIGNATURE="):
            time_signature_str = token.split("=")[-1]
            numerator = int(time_signature_str.split("_")[0])
            denominator = int(time_signature_str.split("_")[-1])
            time_signature = note_sequence.time_signatures.add()
            time_signature.numerator = numerator
            time_signature.denominator = denominator
        elif token.startswith("BPM="):
            bpm_str = token.split("=")[-1]
            bpm = int(bpm_str)
            note_sequence.tempos[0].qpm = bpm
            pulse_duration, bar_duration = duration_in_sec(
                bpm, numerator, denominator
            )
        elif token == "TRACK_START":
            current_bar_index = 0
            track_count += 1
            pass
        elif token == "TRACK_END":
            pass
        elif token == "KEYS_START":
            pass
        elif token == "KEYS_END":
            pass
        elif token.startswith("KEY="):
            pass
        elif token.startswith("INST"):
            instrument = token.split("=")[-1]
            if instrument != "DRUMS" and use_program:
                if instrument_mapper is not None:
                    if instrument in instrument_mapper:
                        instrument = instrument_mapper[instrument]
                current_program = int(instrument)
                current_instrument = track_count
                current_is_drum = False
            if instrument == "DRUMS" and use_drums:
                current_instrument = 0
                current_program = 0
                current_is_drum = True
        elif token == "BAR_START":
            current_time = (current_bar_index * bar_duration)
            current_notes = {}
        elif token == "BAR_END":
            current_bar_index += 1
            pass
        elif token.startswith("NOTE_ON"):
            pitch = int(token.split("=")[-1])
            note = note_sequence.notes.add()
            note.start_time = current_time
            note.end_time = current_time + denominator * pulse_duration
            note.pitch = pitch
            note.instrument = current_instrument
            note.program = current_program
            note.velocity = 80
            note.is_drum = current_is_drum
            current_notes[pitch] = note
        elif token.startswith("NOTE_OFF"):
            pitch = int(token.split("=")[-1])
            if pitch in current_notes:
                note = current_notes[pitch]
                note.end_time = current_time
        elif token.startswith("TIME_DELTA"):
            delta = float(token.split("=")[-1]) * (0.25) * pulse_duration
            current_time += delta
        elif token.startswith("DENSITY="):
            pass
        elif token == "[PAD]":
            pass
        else:
            #print(f"Ignored token {token}.")
            pass

    # Make the instruments right.
    instruments_drums = []
    for note in note_sequence.notes:
        pair = [note.program, note.is_drum]
        if pair not in instruments_drums:
            instruments_drums += [pair]
        note.instrument = instruments_drums.index(pair)

    if only_piano:
        for note in note_sequence.notes:
            if not note.is_drum:
                note.instrument = 0
                note.program = 0

    return note_sequence

def duration_in_sec(bpm, numerator, denominator):
    pulse_duration = BPM_1_SECOND / bpm
    number_of_quarters_per_bar = (4 / denominator) * numerator
    bar_duration = pulse_duration * number_of_quarters_per_bar
    return pulse_duration, bar_duration

def empty_note_sequence(qpm=120, total_time=0.0):
    note_sequence = note_seq.protobuf.music_pb2.NoteSequence()
    note_sequence.tempos.add().qpm = qpm
    #note_sequence.ticks_per_quarter = note_seq.constants.STANDARD_PPQ
    note_sequence.total_time = total_time
    return note_sequence

# %%
note_sequence = token_sequence_to_note_sequence(first_piece)

synth = note_seq.midi_synth.synthesize
note_seq.plot_sequence(note_sequence)
note_seq.play_sequence(note_sequence, synth)
# Out:
#   <div class="bk-root" id="1bbc58e2-6f14-4d5d-8e27-062a1ae4abed" data-root-id="1142"></div>
# <div id="id_2"> </div>

# %% [markdown]
# Download as a MIDI file

# %%
note_seq.note_sequence_to_midi_file(note_sequence, '/content/my_midi.mid')
